# %% [markdown]
# **SWMM5 tutorial 1**
# <br>Uses input files from tutorial included in SWMM5 download.
# <br>https://pyswmm.readthedocs.io/en/stable/tutorial/index.html
#
# *Packages needed:*
# <br>pyswmm
# <br> note: install steps:
# <br> - install using 'pip install pyswmm'
# <br> - download the 64-bit DLL here: https://anaconda.org/OWA/libswmm/files
# <br> - extract the files using 7-zip
# <br> - replace the original DLL (located in C:\Users\Username\Anaconda3\envs\SWMM_env\Lib\site-packages\pyswmm\lib\windows) with the 64-bit DLL
#
# *Files needed:*
# <br> epaswmm5.exe
# <br> tutorial1.inp
# <br> tutorial1.rpt

# %%
#Import python packages
import pyswmm as ps

# %% [markdown]
# Import & run an existing model:

# %%
#Run without interacting with the model
sim = ps.Simulation('tutorial1.inp')
sim.execute()
# Out:
# ... SWMM Version 5.2.0.dev1
# ... Run Complete

# %%
ps.Simulation??
# Out:
# Init signature: ps.Simulation(inputfile, reportfile=None, outputfile=None, swmm_lib_path=None)
# Source:
# class Simulation(object):
#     """
#     Base class for a SWMM Simulation.
#
#     The model object provides several options to run a simulation.
#     User can specified SWMM library path. Uses default lib if not provided.
#
#     Initialize the Simulation class.
#
#     :param str inpfile: Name of SWMM input file (default '')
#     :param str rptfile: Report file to generate (default None)
#     :param str binfile: Optional binary output file (default None)
#     :param str swmm_lib_path: User-specified SWMM library path (default None).
#
#     Examples:
#
#     Intialize a simulation and iterate through a simulation. This
#     approach requires some clean up.
#
#     >>> from pyswmm import Simulation
#     >>>
#     >>> sim = Simulation('tests/data/TestModel1_weirSetting.inp')
#     >>> for step in sim:
#     ...     pass
#     >>>
#     >>> sim.report()
# ...

# %% [markdown]
# with Simulation('./testmodel.inp') as sim:
# ...     for step in sim:
# ...             pass
# ...     sim.report()

# %%
#Import & step through manually
with ps.Simulation('tutorial1.inp') as sim:        #open the model file using a with statement so that it automatically closes itself when done
    for step in sim:                               #for each step
        #pass                                       #placeholder when an indented block is required, but no actions need to happen yet
        print(sim.current_time)                    #print time at current step
    sim.report()
# Out:
# C:\Users\Chloe\Anaconda3\envs\SWMM\lib\site-packages\pyswmm\swmm5.py:167: UserWarning:
#   warnings.warn(self._error_message(errcode))
